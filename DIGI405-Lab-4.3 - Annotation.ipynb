# %% [markdown]
# # DIGI405 Lab 4.3: Annotation

# %% [markdown]
# Use this notebook to annotate an unlabelled sample of tweets from the [Cardiff NLP tweet_eval dataset](https://huggingface.co/datasets/cardiffnlp/tweet_eval) [(Barbieri et al., 2020)](https://arxiv.org/pdf/2010.12421).
#
# * There are 45 tweets in the sample, and you will have the choice of three labels "positive", "negative", or "neutral".
# * For each tweet, you must also provide a score (0-100%) that indicates your confidence that the label is a good fit for the tweet.
#
# ➡️ Run the cells below to load the dataset and start annotating.
#
# ✳️ Do not discuss your annotations with others. After this exercise, your tutor will collate the class annotations and measure agreement using the [Krippendorff's alpha metric](https://www.k-alpha.org/).

# %%
import os
import pandas as pd
import re
import sys

from IPython.display import display, HTML, clear_output

# %%
annotator = os.path.basename(os.path.expanduser("~")).lower()

while not re.fullmatch(r"[a-z]{2,4}\d{1,4}", annotator):
    annotator = input("Enter your UC user ID: ").strip().lower()

print(f"\nAnnotating as {annotator} - saving to 'df_labelled_{annotator}.csv'\n")

# %% [markdown]
# ### Now run the cells below to load the data and begin annotating

# %%
df = pd.read_csv("/scratch/projects/RCH-DIGITEACHING/source-data/sample_tweets_unlabelled.csv")

# %%
# df

# %%
# Instructions
instruction_text = f"""The goal for this task is to identify the sentiment of each tweet as either POSITIVE, NEGATIVE, or NEUTRAL.

Steps:
(1) Run the next cell the load the annotation interface.
(2) Select the sentiment that you feel best represents this tweet from the options POSITIVE, NEGATIVE, or NEUTRAL
(3) Choose a confidence score to represent how confident you are that this label is a good match for the tweet

Your annotations will be saved to a new CSV file called 'df_labelled_{annotator}.csv'
"""

display(HTML(f"""
<div style="background-color:#e6f4ea; border-left:6px solid #2e7d32; border-radius:5px;
            padding:15px 20px; margin:10px 0; color:#1b5e20; font-weight:bold;
            font-size:16px; line-height:1.6; white-space:pre-wrap;">{instruction_text.strip()}</div>
"""))

# %%
# Interface
label_list = ["NEGATIVE",
              "NEUTRAL",
              "POSITIVE",
             ]

labelled_file_name = f"df_labelled_{annotator}.csv"

if "label" not in df.columns:
    df["label"] = None
if "confidence" not in df.columns:
    df["confidence"] = None

# Resume a previous session by matching rows on the tweet text
if os.path.exists(labelled_file_name):
    previous = pd.read_csv(labelled_file_name)
    lookup = previous.set_index("text")[["label", "confidence"]].to_dict("index")
    for idx in df.index:
        hit = lookup.get(df.loc[idx, "text"])
        if hit is not None:
            df.loc[idx, "label"] = hit["label"]
            df.loc[idx, "confidence"] = hit["confidence"]
    print(f"Resumed: restored {len(previous)} previously labelled tweets")
 
labelled_df = df[df["label"].notnull()].copy()
 
def save():
    global labelled_df
    labelled_df = df[df["label"].notnull()].copy()
    labelled_df.to_csv(labelled_file_name, index=False)
 
def show(pos):
    idx = df.index[pos]
    done = int(df["label"].notnull().sum())
    clear_output()
    display(HTML(f"""
    <div style="padding:15px;margin:10px 0;border:1px solid #ddd;border-radius:5px;
                background-color:#f8f9fa;font-size:20px;line-height:1.5;">
        {df.loc[idx, "text"]}
    </div>
    <p><b>Tweet {pos + 1} of {len(df)}</b> &nbsp;|&nbsp;
       labelled: {done} &nbsp;|&nbsp; remaining: {len(df) - done}</p>
    """))
    for n, lab in enumerate(label_list):
        print(f"  [{n}] {lab}")
    print("\n After labelling all the tweets you can use [p] previous or [j N] jump to tweet N to edit. Enter [q] to save and quit at any time. \n")
    existing = df.loc[idx, "label"]
    if pd.notnull(existing):
        existing_conf = df.loc[idx, "confidence"]
        print(f"\n  already labelled: {existing} ({existing_conf})")
    sys.stdout.flush()
    
# Start at the first unlabelled tweet
pos = 0
unlabelled = df.index[df["label"].isnull()]
if len(unlabelled) > 0:
    pos = df.index.get_loc(unlabelled[0])
else:
    print("\nAll tweets have already been annotated.\n")
 
while 0 <= pos < len(df):
    show(pos)
    idx = df.index[pos]
    already_labelled = pd.notnull(df.loc[idx, "label"])
 
    # Keep asking until a valid label or an allowed navigation command is entered
    while True:
        choice = input("Enter the label (0, 1, or 2): ").strip().lower()
        if choice == "q":
            break
        if choice == "p" or choice.startswith("j"):
            # Moving on is only allowed once this tweet has a label
            if already_labelled:
                break
            print("  Please label this tweet before moving on (or q to save and quit)")
            continue
        if choice.isdigit() and int(choice) < len(label_list):
            break
        print(f"  Please enter a number from 0 to {len(label_list) - 1}, or q to save and quit")
 
    if choice == "q":
        save()
        outstanding = int(df["label"].isnull().sum())
        print(f"\nSaved {len(labelled_df)} annotations to {labelled_file_name}\n")
        if outstanding:
            plural = "tweet" if outstanding == 1 else "tweets"
            print(f"{outstanding} {plural} still to do - rerun this cell to carry on")
        break
 
    if choice == "p":
        pos = max(0, pos - 1)
        continue
 
    if choice.startswith("j"):
        bits = choice.split()
        if len(bits) == 2 and bits[1].isdigit() and 0 < int(bits[1]) <= len(df):
            pos = int(bits[1]) - 1
        else:
            print(f"  To jump, enter j followed by a tweet number from 1 to {len(df)}")
        continue
 
    # Keep asking until a valid confidence score is entered
    while True:
        conf = input("How CONFIDENT are you about the label? (scale: 0-100): ").strip()
        if conf.isdigit() and int(conf) <= 100:
            break
        print("  Please enter a whole number from 0 to 100")
 
    df.loc[idx, "label"] = label_list[int(choice)]
    df.loc[idx, "confidence"] = f"{int(conf)}%"
    save()
    pos += 1
 
    # If the end is reached but tweets were skipped, go back to them
    if pos >= len(df):
        remaining = df.index[df["label"].isnull()]
        if len(remaining) > 0:
            pos = df.index.get_loc(remaining[0])
else:
    clear_output()
    save()
    print(f"Annotation complete - {len(labelled_df)} tweets saved to {labelled_file_name}")

# %%
# See annotations in the dataframe
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
labelled_df
